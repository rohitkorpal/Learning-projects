# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitkorpal/Learning-projects/blob/main/IIT_Delhi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
t = sns.load_dataset('titanic')

# %%
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
 t.corr(numeric_only = True)
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#  SexNum     0.543351 -0.131900 -0.093254  0.114631  0.245489  0.182333
# family      0.016639  0.065997 -0.301914  0.890712  0.783111  0.217138
#
#             adult_male     alone    SexNum    family
# survived     -0.557080 -0.203367  0.543351  0.016639
# pclass        0.094035  0.135207 -0.131900  0.065997
# ...

# %%
#label encoding

# %%
t.sex.unique()
#unique value aajate hai column ki
# Out:
# array(['male', 'female'], dtype=object)

# %%
def func(n):
  if n=='male': return 1
  else: return 2

# %%
t[' SexNum']=t.sex.apply(func)
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
t.age.min()
# Out:
# 0.42

# %%
t.age.max()
# Out:
# 80.0

# %%
t.age.mean()
# Out:
# 29.69911764705882

# %%
t.age.var()
# Out:
# 211.01912474630802

# %%
t['family'] = t['sibsp'] + t['parch']
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
t.embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
## filtering
t[t.embarked.isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone   SexNum  family
# 61   woman       False    B         NaN   yes   True        2       0
# 829  woman       False    B         NaN   yes   True        2       0

# %%
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
t.embarked
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embarked, Length: 891, dtype: object

# %%
a=t[(t.pclass==1)&(t.survived==1)&(t.fare>=70)&(t.fare<=100)&(t.deck=="B")]

# %%
a.embarked.value_counts()
# Out:
# S    6
# C    3
# Name: embarked, dtype: int64

# %%
b= t.embarked.value_counts()
b
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
sns.barplot(x = b.index,y=b)
# Out:
# <Axes: xlabel='None', ylabel='embarked'>

# %%
sns.histplot(x=t.age)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.scatterplot(x=t.age)
# Out:
# <Axes: xlabel='age'>

# %%
tc = t.corr(numeric_only = True)

# %%
sns.heatmap(tc, cmap = 'coolwarm', annot = True)
# Out:
# <Axes: >

# %%
sns.boxplot(x = t.fare)
# Out:
# <Axes: xlabel='fare'>
